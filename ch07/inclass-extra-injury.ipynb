# %%
import pandas as pd

df = pd.read_csv('injury-NEISS-2013to17.txt', sep='\t', encoding = "ISO-8859-1")
df
# Out:
#        CPSC_Case_Number Treatment_Date Age  Sex  Race Other_Race  Body_Part  \
# 0             130104962     01/01/2013  57    1   1.0        NaN       76.0
# 1             130104974     01/01/2013  39    2   1.0        NaN       34.0
# 2             130105224     01/01/2013  34    1   1.0        NaN       37.0
# 3             130107099     01/01/2013  20    2   1.0        NaN       76.0
# 4             130107326     01/01/2013  35    1   1.0        NaN       31.0
# 5             130107485     01/02/2013  36    1   0.0        NaN       79.0
# 6             130107533     01/02/2013  24    2   0.0        NaN       75.0
# 7             130107535     01/02/2013  13    1   2.0        NaN       93.0
# 8             130107541     01/02/2013  13    2   2.0        NaN       75.0
# 9             130107752     01/01/2013  29    1   1.0        NaN       85.0
# 10            130108139     01/01/2013   5    1   1.0        NaN       88.0
# ...
